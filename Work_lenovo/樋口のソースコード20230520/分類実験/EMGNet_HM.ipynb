# %% [markdown]
# #自作データセット
#
# ジェスチャ：6種類
#
# 準拠するパラメータ：
#
# ・batch size = 128
#
# ・L2正則化の重み = 0.001
#
# ・学習率減衰：1~19 = 0.01, 20~39 = 0.001, 40~50 = 0.0001
#
# ・データ比：train:valid:test = 6:1:3

# %%
# !nvidia-smi
# Out:
# Wed Dec 21 20:26:56 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 516.94       Driver Version: 516.94       CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# |  0%   36C    P8    21W / 350W |  10033MiB / 24576MiB |     26%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2256    C+G   ...bbwe\Microsoft.Photos.exe    N/A      |
# |    0   N/A  N/A      2964    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A      7324    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A      8408      C   ...thon\Python310\python.exe    N/A      |
# |    0   N/A  N/A      8956    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A      9812    C+G   ...werToys.ColorPickerUI.exe    N/A      |
# |    0   N/A  N/A      9932    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     10056    C+G   ...\PowerToys.FancyZones.exe    N/A      |
# |    0   N/A  N/A     10468    C+G   ...werToys.PowerLauncher.exe    N/A      |
# |    0   N/A  N/A     10844    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     11872    C+G   ...icrosoft VS Code\Code.exe    N/A      |
# |    0   N/A  N/A     15432    C+G   ...kzcwy\mcafee-security.exe    N/A      |
# |    0   N/A  N/A     15524    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     15988    C+G   ...4__8j3eq9eme6ctt\IGCC.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# dataset
# バッチサイズ→128
# テストデータ割合→10%

# %% [markdown]
# データセットの解凍

# %%
#import keras
import glob
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import Dense, Dropout, Flatten
#from tensorflow.keras.layers.advanced_activations import PReLU
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler #学習率減衰
from tensorflow.keras import regularizers #L2正則化
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import time
import tensorflow as tf
import os

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'#GPUのメモリ確保を制限

#乱数の設定
os.environ['PYTHONHASHSEED'] = '0'
tf.random.set_seed(1)
np.random.seed(1)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

# %% [markdown]
# 各種設定(データセットの指定など)

# %%
train_data_path = 'datasetHM' #データセットのフォルダ名
folder = os.listdir(train_data_path) #データセットのクラス名
print(folder)

class_number = len(folder)
print('分類するクラス数: ', class_number)
# Out:
# ['1', '2', '3', '4', '5', '6']
# 分類するクラス数:  6

# %% [markdown]
# データセットの読み込み・準備

# %%
for index, name in enumerate(folder): #name:クラスフォルダ名, index:クラスに対応している変数
  read_data = train_data_path + '/' + name

  files = glob.glob(read_data + '/*.npy') #クラスごとのファイルすべてを格納
  print('--- 読み込んだデータセットは', read_data, 'です。')
  for i, file in enumerate(files):  #i:クラス内の各ファイルに対応している変数
    print('\r', read_data, ': ', i+1, '/', len(files), end='')
    array = np.load(file)
    np.save(file, array[:, :, :3])
# Out:
# --- 読み込んだデータセットは datasetHM/1 です。
#  datasetHM/1 :  132966 / 132966--- 読み込んだデータセットは datasetHM/2 です。
#  datasetHM/2 :  133494 / 133494--- 読み込んだデータセットは datasetHM/3 です。
#  datasetHM/3 :  133599 / 133599--- 読み込んだデータセットは datasetHM/4 です。
#  datasetHM/4 :  133457 / 133457--- 読み込んだデータセットは datasetHM/5 です。
#  datasetHM/5 :  133423 / 133423--- 読み込んだデータセットは datasetHM/6 です。
#  datasetHM/6 :  133997 / 133997

# %%
start = time.time()
X_image = []
Y_label = []
Xappend = X_image.append
Yappend = Y_label.append

#クラスごとのループ
for index, name in enumerate(folder): #name:クラスフォルダ名, index:クラスに対応している変数
  read_data = train_data_path + '/' + name

  files = glob.glob(read_data + '/*.npy') #クラスごとのファイルすべてを格納
  print('--- 読み込んだデータセットは', read_data, 'です。')

  #ファイルごとのループ
  for i, file in enumerate(files):  #i:クラス内の各ファイルに対応している変数
    print('\r', read_data, ': ', i+1, '/', len(files), end='')
    array = np.load(file)

    Xappend(array) #画像データをndarrayとして格納
    Yappend(index) #画像に対応したクラス(画像ラベル)を格納

  print(' --finish: ' + str(int((time.time()-start)/60)) + 'm' + str(int((time.time()-start))%60) + 's')
  
#データセット配列の設定
X_image = np.array(X_image) #データセット全体の画像行列データ＝入力データ
Y_label = np.array(Y_label) #データセット全体の画像ラベル
# Out:
# --- 読み込んだデータセットは datasetHM/1 です。
#  datasetHM/1 :  132966 / 132966 --finish: 8m25s
# --- 読み込んだデータセットは datasetHM/2 です。
#  datasetHM/2 :  133494 / 133494 --finish: 16m38s
# --- 読み込んだデータセットは datasetHM/3 です。
#  datasetHM/3 :  133599 / 133599 --finish: 24m59s
# --- 読み込んだデータセットは datasetHM/4 です。
#  datasetHM/4 :  133457 / 133457 --finish: 33m11s
# --- 読み込んだデータセットは datasetHM/5 です。
#  datasetHM/5 :  133423 / 133423 --finish: 41m30s
# --- 読み込んだデータセットは datasetHM/6 です。
#  datasetHM/6 :  133997 / 133997 --finish: 50m6s

# %% [markdown]
# ch数(1~7)を指定したCNNモデル

# %%
tf.test.gpu_device_name()

#画像行列データを正規化
x_max = X_image.max()
x_min = X_image.min()
print(x_max, x_min)
scale = (x_max - x_min)/2
med = (x_max + x_min)/2
for i in range(len(X_image)):
    X_image[i, :, :, :] = (X_image[i, :, :, :] - med)/scale
print(X_image.max(), X_image.min())

Y_label = to_categorical(Y_label, class_number) #Kerasではクラスをベクトルで扱うらしい【おまじない】

#訓練データとテストデータを分割。
x_train, valid_images, y_train, valid_labels = train_test_split(X_image, Y_label, test_size=0.4, random_state=0)
x_valid, x_test, y_valid, y_test = train_test_split(valid_images, valid_labels, test_size=0.75, random_state=0)

print('train data size: ', len(x_train))
print('valid data size: ', len(x_valid))
print('test data size: ', len(x_test))
# Out:
# 1.9138139918798982 -0.7468896857262057
# 1.0 -1.0
# train data size:  480561
# valid data size:  80093
# test data size:  240282

# %%
#print(X_image.shape)
# Out:
# (800936, 25, 15, 8)

# %%
BATCH_SIZE = 128
image_size_x = 25 #画像サイズ
image_size_y = 15
channel = 3
epochnumber = 50
L2weight = 0.001 #Myo: 0.01, Nina: 0.001

#CNNアーキテクチャの設計
model = Sequential()

model.add(BatchNormalization(input_shape=(image_size_x, image_size_y, channel)))
model.add(Activation('relu'))
model.add(Conv2D(16, (3, 3), padding='same'))

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3), padding='same'))

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3), padding='same'))

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3), padding='same'))

model.add(GlobalAveragePooling2D())

model.add(Dense(class_number, activation='softmax', kernel_regularizer=regularizers.l2(L2weight)))

model.summary()

#学習率減衰の設定
def step_decay(epoch):
    x = 0.01
    if epoch >= 20: x = 0.001
    if epoch >= 40: x = 0.0001
    return x
lr_decay = LearningRateScheduler(step_decay)

model.compile(loss='categorical_crossentropy', #損失関数の設定
            optimizer=Adam(learning_rate=0.01), #最適化アルゴリズムの設定
            metrics=['accuracy'] #評価関数の設定
            )

start_time = time.time()

#可視化
history = model.fit(x_train, y_train, 
                    batch_size=BATCH_SIZE, 
                    epochs=epochnumber, 
                    verbose=1, #学習過程を出力するかどうか
                    validation_data=(x_valid, y_valid), 
                    callbacks=[lr_decay] #学習率減衰の設定
                    )

print('Computation time: {0:.3f} sec'.format(time.time() - start_time))

model.save('model/EMGNet_HM.h5') #モデルの保存
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 25, 15, 3)        12
#  ormalization)
#
#  activation (Activation)     (None, 25, 15, 3)         0
#
#  conv2d (Conv2D)             (None, 25, 15, 16)        448
#
#  batch_normalization_1 (Batc  (None, 25, 15, 16)       64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 25, 15, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 25, 15, 32)        4640
#
#  batch_normalization_2 (Batc  (None, 25, 15, 32)       128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 25, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 25, 15, 32)        9248
#
#  batch_normalization_3 (Batc  (None, 25, 15, 32)       128
#  hNormalization)
#
#  activation_3 (Activation)   (None, 25, 15, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 25, 15, 64)        18496
#
#  global_average_pooling2d (G  (None, 64)               0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 6)                 390
#
# =================================================================
# Total params: 33,554
# Trainable params: 33,388
# Non-trainable params: 166
# _________________________________________________________________
# Epoch 1/50
# 3755/3755 [==============================] - 34s 7ms/step - loss: 1.3280 - accuracy: 0.4510 - val_loss: 1.3604 - val_accuracy: 0.4657 - lr: 0.0100
# Epoch 2/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.2156 - accuracy: 0.5027 - val_loss: 1.8478 - val_accuracy: 0.3957 - lr: 0.0100
# Epoch 3/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1872 - accuracy: 0.5131 - val_loss: 1.2513 - val_accuracy: 0.4849 - lr: 0.0100
# Epoch 4/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1753 - accuracy: 0.5184 - val_loss: 1.2101 - val_accuracy: 0.4989 - lr: 0.0100
# Epoch 5/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1657 - accuracy: 0.5222 - val_loss: 1.2391 - val_accuracy: 0.5027 - lr: 0.0100
# Epoch 6/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1562 - accuracy: 0.5259 - val_loss: 1.1867 - val_accuracy: 0.5191 - lr: 0.0100
# Epoch 7/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1499 - accuracy: 0.5291 - val_loss: 1.1973 - val_accuracy: 0.5182 - lr: 0.0100
# Epoch 8/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1449 - accuracy: 0.5303 - val_loss: 1.1655 - val_accuracy: 0.5210 - lr: 0.0100
# Epoch 9/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1404 - accuracy: 0.5331 - val_loss: 1.1935 - val_accuracy: 0.5115 - lr: 0.0100
# Epoch 10/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1363 - accuracy: 0.5341 - val_loss: 1.1705 - val_accuracy: 0.5215 - lr: 0.0100
# Epoch 11/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1316 - accuracy: 0.5363 - val_loss: 1.1333 - val_accuracy: 0.5376 - lr: 0.0100
# Epoch 12/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1286 - accuracy: 0.5372 - val_loss: 1.1360 - val_accuracy: 0.5324 - lr: 0.0100
# Epoch 13/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1244 - accuracy: 0.5390 - val_loss: 1.3232 - val_accuracy: 0.4774 - lr: 0.0100
# Epoch 14/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1232 - accuracy: 0.5392 - val_loss: 1.1160 - val_accuracy: 0.5423 - lr: 0.0100
# Epoch 15/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1212 - accuracy: 0.5398 - val_loss: 1.1445 - val_accuracy: 0.5327 - lr: 0.0100
# Epoch 16/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1182 - accuracy: 0.5417 - val_loss: 1.1376 - val_accuracy: 0.5314 - lr: 0.0100
# Epoch 17/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1165 - accuracy: 0.5421 - val_loss: 1.4036 - val_accuracy: 0.4651 - lr: 0.0100
# Epoch 18/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1146 - accuracy: 0.5428 - val_loss: 1.1458 - val_accuracy: 0.5335 - lr: 0.0100
# Epoch 19/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1121 - accuracy: 0.5446 - val_loss: 1.1370 - val_accuracy: 0.5368 - lr: 0.0100
# Epoch 20/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.1099 - accuracy: 0.5453 - val_loss: 1.1308 - val_accuracy: 0.5379 - lr: 0.0100
# Epoch 21/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0823 - accuracy: 0.5568 - val_loss: 1.0808 - val_accuracy: 0.5584 - lr: 0.0010
# Epoch 22/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0792 - accuracy: 0.5584 - val_loss: 1.0832 - val_accuracy: 0.5557 - lr: 0.0010
# Epoch 23/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0784 - accuracy: 0.5581 - val_loss: 1.0796 - val_accuracy: 0.5575 - lr: 0.0010
# Epoch 24/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0771 - accuracy: 0.5588 - val_loss: 1.0804 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 25/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0764 - accuracy: 0.5592 - val_loss: 1.0777 - val_accuracy: 0.5594 - lr: 0.0010
# Epoch 26/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0762 - accuracy: 0.5595 - val_loss: 1.0819 - val_accuracy: 0.5573 - lr: 0.0010
# Epoch 27/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0760 - accuracy: 0.5597 - val_loss: 1.0941 - val_accuracy: 0.5539 - lr: 0.0010
# Epoch 28/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0760 - accuracy: 0.5598 - val_loss: 1.0778 - val_accuracy: 0.5583 - lr: 0.0010
# Epoch 29/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0749 - accuracy: 0.5598 - val_loss: 1.0925 - val_accuracy: 0.5524 - lr: 0.0010
# Epoch 30/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0750 - accuracy: 0.5595 - val_loss: 1.0787 - val_accuracy: 0.5582 - lr: 0.0010
# Epoch 31/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0745 - accuracy: 0.5602 - val_loss: 1.0814 - val_accuracy: 0.5588 - lr: 0.0010
# Epoch 32/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0739 - accuracy: 0.5603 - val_loss: 1.0781 - val_accuracy: 0.5595 - lr: 0.0010
# Epoch 33/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0732 - accuracy: 0.5604 - val_loss: 1.0790 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 34/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0730 - accuracy: 0.5609 - val_loss: 1.0743 - val_accuracy: 0.5612 - lr: 0.0010
# Epoch 35/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0725 - accuracy: 0.5612 - val_loss: 1.0772 - val_accuracy: 0.5594 - lr: 0.0010
# Epoch 36/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0726 - accuracy: 0.5609 - val_loss: 1.0797 - val_accuracy: 0.5580 - lr: 0.0010
# Epoch 37/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0726 - accuracy: 0.5616 - val_loss: 1.0848 - val_accuracy: 0.5553 - lr: 0.0010
# Epoch 38/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0724 - accuracy: 0.5607 - val_loss: 1.0802 - val_accuracy: 0.5570 - lr: 0.0010
# Epoch 39/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0716 - accuracy: 0.5609 - val_loss: 1.0808 - val_accuracy: 0.5576 - lr: 0.0010
# Epoch 40/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0720 - accuracy: 0.5610 - val_loss: 1.0738 - val_accuracy: 0.5604 - lr: 0.0010
# Epoch 41/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0685 - accuracy: 0.5626 - val_loss: 1.0712 - val_accuracy: 0.5616 - lr: 1.0000e-04
# Epoch 42/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0675 - accuracy: 0.5627 - val_loss: 1.0713 - val_accuracy: 0.5616 - lr: 1.0000e-04
# Epoch 43/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0674 - accuracy: 0.5631 - val_loss: 1.0711 - val_accuracy: 0.5614 - lr: 1.0000e-04
# Epoch 44/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0680 - accuracy: 0.5633 - val_loss: 1.0709 - val_accuracy: 0.5618 - lr: 1.0000e-04
# Epoch 45/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0676 - accuracy: 0.5633 - val_loss: 1.0712 - val_accuracy: 0.5613 - lr: 1.0000e-04
# Epoch 46/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0678 - accuracy: 0.5631 - val_loss: 1.0711 - val_accuracy: 0.5616 - lr: 1.0000e-04
# Epoch 47/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0677 - accuracy: 0.5633 - val_loss: 1.0712 - val_accuracy: 0.5616 - lr: 1.0000e-04
# Epoch 48/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0676 - accuracy: 0.5629 - val_loss: 1.0711 - val_accuracy: 0.5613 - lr: 1.0000e-04
# Epoch 49/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0678 - accuracy: 0.5629 - val_loss: 1.0716 - val_accuracy: 0.5610 - lr: 1.0000e-04
# Epoch 50/50
# 3755/3755 [==============================] - 26s 7ms/step - loss: 1.0673 - accuracy: 0.5630 - val_loss: 1.0711 - val_accuracy: 0.5608 - lr: 1.0000e-04
# Computation time: 1318.089 sec

# %% [markdown]
# 学習曲線の作図(保存したモデルを呼び出して実行)

# %%
model = load_model('model/EMGNet_HM.h5')

#作図
x = range(1, epochnumber+1)
plt.plot(x, history.history['accuracy'])
plt.plot(x, history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Valid'], loc='lower right')
plt.show()

plt.plot(x, history.history['loss'])
plt.plot(x, history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
#plt.ylim(0, 8)
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Valid'], loc='upper right')
plt.show()

# %% [markdown]
# テスト・混同行列の作成(参考：https://newtechnologylifestyle.net/keras_fashion-mnist/)(https://kinpatucom821.hatenablog.com/entry/2018/08/30/215419)

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues
                          ):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

pred_y = model.predict(x_test)
pred_y_classes = np.argmax(pred_y,axis = 1) 
tue_y= np.argmax(y_test,axis = 1) 
confusion_mtx = confusion_matrix(tue_y, pred_y_classes) 
plot_confusion_matrix(confusion_mtx, classes = range(1, 7)) 
plt.show()

score = model.evaluate(x_test, y_test, verbose=0)
print('Loss:', score[0], '（損失関数値 - 0に近いほど正解に近い）') 
print('Accuracy:', score[1] * 100, '%', '（精度 - 100% に近いほど正解に近い）')
# Out:
# 7509/7509 [==============================] - 11s 1ms/step
# Confusion matrix, without normalization
# [[33989  3148   476  1727   451    84]
#  [ 2940 27429  4281  1440  3169   859]
#  [  630  5375 16540  5021  5066  7371]
#  [ 2239  1478  3976 22934  3786  6008]
#  [ 1023  6882  7342  7177  9700  7705]
#  [  128  1435  6330  4360  3313 24470]]
# Loss: 1.0720974206924438 （損失関数値 - 0に近いほど正解に近い）
# Accuracy: 56.209784746170044 % （精度 - 100% に近いほど正解に近い）

# %%
print(confusion_mtx)
# Out:
# [[33989  3148   476  1727   451    84]
#  [ 2940 27429  4281  1440  3169   859]
#  [  630  5375 16540  5021  5066  7371]
#  [ 2239  1478  3976 22934  3786  6008]
#  [ 1023  6882  7342  7177  9700  7705]
#  [  128  1435  6330  4360  3313 24470]]

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
import itertools

#model = load_model('model/EMGNet_Nina_B6_1.h5')

def plot_confusion_matrix(cm, classes,
                          normalize=True,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues
                          ):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    #plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

confusion_mtx = [[33989,  3148,   476,  1727,   451,    84],
                 [ 2940, 27429,  4281,  1440,  3169,   859],
                 [  630,  5375, 16540,  5021,  5066,  7371],
                 [ 2239,  1478,  3976, 22934,  3786,  6008],
                 [ 1023,  6882,  7342,  7177,  9700,  7705],
                 [  128,  1435,  6330,  4360,  3313, 24470]]
mtx = np.array(confusion_mtx)
#mtx = mtx[[5,1,3,0,2,4]]
#mtx = mtx[:,[5,1,3,0,2,4]]

plot_confusion_matrix(mtx, classes = range(1, 7)) 
plt.show()
# Out:
# Normalized confusion matrix
# [[0.85238871 0.07894671 0.0119373  0.04331034 0.01131034 0.00210658]
#  [0.07328381 0.68370806 0.1067102  0.03589411 0.07899197 0.02141184]
#  [0.01574882 0.13436492 0.41346899 0.12551559 0.1266405  0.18426118]
#  [0.055392   0.03656515 0.09836471 0.56737834 0.09366418 0.14863561]
#  [0.0256848  0.17278867 0.18433805 0.18019534 0.24354114 0.19345201]
#  [0.00319712 0.03584274 0.1581077  0.10890199 0.08275052 0.61119992]]
