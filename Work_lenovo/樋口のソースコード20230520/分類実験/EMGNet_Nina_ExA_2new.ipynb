# %% [markdown]
# #NinaPro DB5 dataset(電極番号1~8)
#
# ジェスチャ：6種類
#
# 準拠するパラメータ：
#
# ・batch size = 128
#
# ・L2正則化の重み = 0.001
#
# ・学習率減衰：1~19 = 0.01, 20~39 = 0.001, 40~50 = 0.0001
#
# ・データ比：train:valid:test = 6:1:3

# %%
# !nvidia-smi
# Out:
# Wed Dec 21 16:47:22 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 516.94       Driver Version: 516.94       CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# |  0%   32C    P8    21W / 350W |  13794MiB / 24576MiB |     31%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A         8    C+G   ...oot\Office16\POWERPNT.EXE    N/A      |
# |    0   N/A  N/A      2256    C+G   ...bbwe\Microsoft.Photos.exe    N/A      |
# |    0   N/A  N/A      2964    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A      6592      C   ...thon\Python310\python.exe    N/A      |
# |    0   N/A  N/A      7324    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A      8408      C   ...thon\Python310\python.exe    N/A      |
# |    0   N/A  N/A      8956    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A      9812    C+G   ...werToys.ColorPickerUI.exe    N/A      |
# |    0   N/A  N/A      9932    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     10056    C+G   ...\PowerToys.FancyZones.exe    N/A      |
# |    0   N/A  N/A     10468    C+G   ...werToys.PowerLauncher.exe    N/A      |
# |    0   N/A  N/A     10844    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     11872    C+G   ...icrosoft VS Code\Code.exe    N/A      |
# |    0   N/A  N/A     15432    C+G   ...kzcwy\mcafee-security.exe    N/A      |
# |    0   N/A  N/A     15524    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     15640    C+G   ...e\PhoneExperienceHost.exe    N/A      |
# |    0   N/A  N/A     15716    C+G   ...e\root\Office16\EXCEL.EXE    N/A      |
# |    0   N/A  N/A     15988    C+G   ...4__8j3eq9eme6ctt\IGCC.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# dataset
# バッチサイズ→128
# テストデータ割合→10%

# %% [markdown]
# データセットの解凍

# %%
#import keras
import glob
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import Dense, Dropout, Flatten
#from tensorflow.keras.layers.advanced_activations import PReLU
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler #学習率減衰
from tensorflow.keras import regularizers #L2正則化
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import time
import tensorflow as tf
import os

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'#GPUのメモリ確保を制限

#乱数の設定
os.environ['PYTHONHASHSEED'] = '0'
tf.random.set_seed(1)
np.random.seed(1)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

#メモリの解放
import gc
gc.collect()

tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# 各種設定(データセットの指定など)

# %%
train_data_path = 'datasetNina_ExA_2' #データセットのフォルダ名
folder = os.listdir(train_data_path) #データセットのクラス名
print(folder)

class_number = len(folder)
print('分類するクラス数: ', class_number)
# Out:
# ['1', '10', '11', '12', '2', '3', '4', '5', '6', '7', '8', '9']
# 分類するクラス数:  12

# %% [markdown]
# データセットの読み込み・準備

# %%
start = time.time()
X_image = []
Y_label = []
Xappend = X_image.append
Yappend = Y_label.append

#クラスごとのループ
for index, name in enumerate(folder): #name:クラスフォルダ名, index:クラスに対応している変数
  read_data = train_data_path + '/' + name

  files = glob.glob(read_data + '/*.npy') #クラスごとのファイルすべてを格納
  #print('--- 読み込んだデータセットは', read_data, 'です。')

  #ファイルごとのループ
  for i, file in enumerate(files):  #i:クラス内の各ファイルに対応している変数
    print('\r', read_data, ': ', i+1, '/', len(files), end='')
    array = np.load(file)

    Xappend(array) #画像データをndarrayとして格納
    Yappend(index) #画像に対応したクラス(画像ラベル)を格納

  print(' --finish: ' + str(int((time.time()-start)/60)) + 'm' + str(int((time.time()-start))%60) + 's')
  
#データセット配列の設定
X_image = np.array(X_image) #データセット全体の画像行列データ＝入力データ
Y_label = np.array(Y_label) #データセット全体の画像ラベル

#画像行列データを正規化
print(X_image.max(), X_image.min())
scale = (X_image.max() - X_image.min())/2
med = (X_image.max() + X_image.min())/2
X_image = (X_image - med)/scale
print(X_image.max(), X_image.min())

Y_label = to_categorical(Y_label, class_number) #Kerasではクラスをベクトルで扱うらしい【おまじない】

#訓練データとテストデータを分割。
x_train, valid_images, y_train, valid_labels = train_test_split(X_image, Y_label, test_size=0.4, random_state=0)
x_valid, x_test, y_valid, y_test = train_test_split(valid_images, valid_labels, test_size=0.75, random_state=0)

print('train data size: ', len(x_train))
print('valid data size: ', len(x_valid))
print('test data size: ', len(x_test))
# Out:
#  datasetNina_ExA_2/1 :  10979 / 10979 --finish: 0m43s
#  datasetNina_ExA_2/10 :  8839 / 8839 --finish: 1m18s
#  datasetNina_ExA_2/11 :  6937 / 6937 --finish: 1m45s
#  datasetNina_ExA_2/12 :  7879 / 7879 --finish: 2m17s
#  datasetNina_ExA_2/2 :  7828 / 7828 --finish: 2m46s
#  datasetNina_ExA_2/3 :  10032 / 10032 --finish: 3m26s
#  datasetNina_ExA_2/4 :  7665 / 7665 --finish: 3m58s
#  datasetNina_ExA_2/5 :  8755 / 8755 --finish: 4m33s
#  datasetNina_ExA_2/6 :  8898 / 8898 --finish: 5m7s
#  datasetNina_ExA_2/7 :  10038 / 10038 --finish: 5m49s
#  datasetNina_ExA_2/8 :  8490 / 8490 --finish: 6m25s
#  datasetNina_ExA_2/9 :  7183 / 7183 --finish: 6m57s
# 463.8880948803402 -154.92180442050878
# 1.0 -0.9999999999999998
# train data size:  62113
# valid data size:  10352
# test data size:  31058

# %% [markdown]
# ch数(1~7)を指定したCNNモデル

# %%
BATCH_SIZE = 128
image_size_x = 25 #画像サイズ
image_size_y = 15
channel = 8 
epochnumber = 50
L2weight = 0.001 #Myo: 0.01, Nina: 0.001

#CNNアーキテクチャの設計
model = Sequential()

model.add(BatchNormalization(input_shape=(image_size_x, image_size_y, channel)))
model.add(Activation('relu'))
model.add(Conv2D(16, (3, 3), padding='same'))

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3), padding='same'))

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3), padding='same'))

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3), padding='same'))

model.add(GlobalAveragePooling2D())

model.add(Dense(class_number, activation='softmax', kernel_regularizer=regularizers.l2(L2weight)))

model.summary()

#学習率減衰の設定
def step_decay(epoch):
    x = 0.01
    if epoch >= 20: x = 0.001
    if epoch >= 40: x = 0.0001
    return x
lr_decay = LearningRateScheduler(step_decay)

model.compile(loss='categorical_crossentropy', #損失関数の設定
            optimizer=Adam(learning_rate=0.01), #最適化アルゴリズムの設定
            metrics=['accuracy'] #評価関数の設定
            )

start_time = time.time()

#可視化
history = model.fit(x_train, y_train, 
                    batch_size=BATCH_SIZE, 
                    epochs=epochnumber, 
                    verbose=1, #学習過程を出力するかどうか
                    validation_data=(x_valid, y_valid), 
                    callbacks=[lr_decay] #学習率減衰の設定
                    )

print('Computation time: {0:.3f} sec'.format(time.time() - start_time))

model.save('model/EMGNet_Nina_ExA_2.h5') #モデルの保存
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 25, 15, 8)        32
#  ormalization)
#
#  activation (Activation)     (None, 25, 15, 8)         0
#
#  conv2d (Conv2D)             (None, 25, 15, 16)        1168
#
#  batch_normalization_1 (Batc  (None, 25, 15, 16)       64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 25, 15, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 25, 15, 32)        4640
#
#  batch_normalization_2 (Batc  (None, 25, 15, 32)       128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 25, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 25, 15, 32)        9248
#
#  batch_normalization_3 (Batc  (None, 25, 15, 32)       128
#  hNormalization)
#
#  activation_3 (Activation)   (None, 25, 15, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 25, 15, 64)        18496
#
#  global_average_pooling2d (G  (None, 64)               0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 12)                780
#
# =================================================================
# Total params: 34,684
# Trainable params: 34,508
# Non-trainable params: 176
# _________________________________________________________________
# Epoch 1/50
# 486/486 [==============================] - 7s 9ms/step - loss: 1.7573 - accuracy: 0.3827 - val_loss: 1.9083 - val_accuracy: 0.3430 - lr: 0.0100
# Epoch 2/50
# 486/486 [==============================] - 4s 8ms/step - loss: 1.4608 - accuracy: 0.4913 - val_loss: 1.4529 - val_accuracy: 0.4992 - lr: 0.0100
# Epoch 3/50
# 486/486 [==============================] - 4s 8ms/step - loss: 1.3674 - accuracy: 0.5273 - val_loss: 1.4655 - val_accuracy: 0.4957 - lr: 0.0100
# Epoch 4/50
# 486/486 [==============================] - 4s 7ms/step - loss: 1.3025 - accuracy: 0.5529 - val_loss: 1.4466 - val_accuracy: 0.5234 - lr: 0.0100
# Epoch 5/50
# 486/486 [==============================] - 4s 8ms/step - loss: 1.2695 - accuracy: 0.5659 - val_loss: 1.4764 - val_accuracy: 0.5169 - lr: 0.0100
# Epoch 6/50
# 486/486 [==============================] - 4s 8ms/step - loss: 1.2425 - accuracy: 0.5750 - val_loss: 1.2431 - val_accuracy: 0.5728 - lr: 0.0100
# Epoch 7/50
# 486/486 [==============================] - 4s 8ms/step - loss: 1.2172 - accuracy: 0.5854 - val_loss: 1.3498 - val_accuracy: 0.5455 - lr: 0.0100
# Epoch 8/50
# 486/486 [==============================] - 4s 7ms/step - loss: 1.2008 - accuracy: 0.5912 - val_loss: 1.2784 - val_accuracy: 0.5695 - lr: 0.0100
# Epoch 9/50
# 486/486 [==============================] - 4s 7ms/step - loss: 1.1863 - accuracy: 0.5944 - val_loss: 1.1989 - val_accuracy: 0.5943 - lr: 0.0100
# Epoch 10/50
# 486/486 [==============================] - 4s 7ms/step - loss: 1.1715 - accuracy: 0.5989 - val_loss: 1.2228 - val_accuracy: 0.5914 - lr: 0.0100
# Epoch 11/50
# 486/486 [==============================] - 4s 7ms/step - loss: 1.1579 - accuracy: 0.6051 - val_loss: 1.2025 - val_accuracy: 0.5972 - lr: 0.0100
# Epoch 12/50
# 486/486 [==============================] - 4s 7ms/step - loss: 1.1442 - accuracy: 0.6113 - val_loss: 1.1716 - val_accuracy: 0.6040 - lr: 0.0100
# Epoch 13/50
# 486/486 [==============================] - 4s 7ms/step - loss: 1.1391 - accuracy: 0.6099 - val_loss: 1.2775 - val_accuracy: 0.5776 - lr: 0.0100
# Epoch 14/50
# 486/486 [==============================] - 4s 8ms/step - loss: 1.1221 - accuracy: 0.6179 - val_loss: 1.1498 - val_accuracy: 0.6156 - lr: 0.0100
# Epoch 15/50
# 486/486 [==============================] - 4s 8ms/step - loss: 1.1123 - accuracy: 0.6213 - val_loss: 1.2200 - val_accuracy: 0.6021 - lr: 0.0100
# Epoch 16/50
# 486/486 [==============================] - 4s 8ms/step - loss: 1.1093 - accuracy: 0.6240 - val_loss: 1.1351 - val_accuracy: 0.6135 - lr: 0.0100
# Epoch 17/50
# 486/486 [==============================] - 4s 7ms/step - loss: 1.0995 - accuracy: 0.6254 - val_loss: 1.1186 - val_accuracy: 0.6190 - lr: 0.0100
# Epoch 18/50
# 486/486 [==============================] - 4s 8ms/step - loss: 1.0911 - accuracy: 0.6309 - val_loss: 1.1580 - val_accuracy: 0.6165 - lr: 0.0100
# Epoch 19/50
# 486/486 [==============================] - 4s 8ms/step - loss: 1.0787 - accuracy: 0.6319 - val_loss: 1.0498 - val_accuracy: 0.6470 - lr: 0.0100
# Epoch 20/50
# 486/486 [==============================] - 4s 8ms/step - loss: 1.0728 - accuracy: 0.6369 - val_loss: 1.1459 - val_accuracy: 0.6151 - lr: 0.0100
# Epoch 21/50
# 486/486 [==============================] - 4s 8ms/step - loss: 0.9813 - accuracy: 0.6683 - val_loss: 0.9536 - val_accuracy: 0.6821 - lr: 0.0010
# Epoch 22/50
# 486/486 [==============================] - 4s 8ms/step - loss: 0.9661 - accuracy: 0.6739 - val_loss: 0.9608 - val_accuracy: 0.6816 - lr: 0.0010
# Epoch 23/50
# 486/486 [==============================] - 4s 8ms/step - loss: 0.9615 - accuracy: 0.6746 - val_loss: 0.9483 - val_accuracy: 0.6841 - lr: 0.0010
# Epoch 24/50
# 486/486 [==============================] - 4s 8ms/step - loss: 0.9583 - accuracy: 0.6773 - val_loss: 0.9525 - val_accuracy: 0.6837 - lr: 0.0010
# Epoch 25/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9577 - accuracy: 0.6771 - val_loss: 0.9408 - val_accuracy: 0.6863 - lr: 0.0010
# Epoch 26/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9564 - accuracy: 0.6775 - val_loss: 0.9421 - val_accuracy: 0.6855 - lr: 0.0010
# Epoch 27/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9534 - accuracy: 0.6786 - val_loss: 0.9335 - val_accuracy: 0.6904 - lr: 0.0010
# Epoch 28/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9525 - accuracy: 0.6781 - val_loss: 0.9321 - val_accuracy: 0.6877 - lr: 0.0010
# Epoch 29/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9508 - accuracy: 0.6782 - val_loss: 0.9360 - val_accuracy: 0.6924 - lr: 0.0010
# Epoch 30/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9481 - accuracy: 0.6788 - val_loss: 0.9313 - val_accuracy: 0.6889 - lr: 0.0010
# Epoch 31/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9430 - accuracy: 0.6826 - val_loss: 0.9438 - val_accuracy: 0.6857 - lr: 0.0010
# Epoch 32/50
# 486/486 [==============================] - 4s 8ms/step - loss: 0.9438 - accuracy: 0.6814 - val_loss: 0.9380 - val_accuracy: 0.6900 - lr: 0.0010
# Epoch 33/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9444 - accuracy: 0.6815 - val_loss: 0.9312 - val_accuracy: 0.6884 - lr: 0.0010
# Epoch 34/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9419 - accuracy: 0.6822 - val_loss: 0.9286 - val_accuracy: 0.6898 - lr: 0.0010
# Epoch 35/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9415 - accuracy: 0.6833 - val_loss: 0.9337 - val_accuracy: 0.6904 - lr: 0.0010
# Epoch 36/50
# 486/486 [==============================] - 4s 8ms/step - loss: 0.9413 - accuracy: 0.6835 - val_loss: 0.9339 - val_accuracy: 0.6892 - lr: 0.0010
# Epoch 37/50
# 486/486 [==============================] - 4s 8ms/step - loss: 0.9428 - accuracy: 0.6810 - val_loss: 0.9246 - val_accuracy: 0.6933 - lr: 0.0010
# Epoch 38/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9430 - accuracy: 0.6808 - val_loss: 0.9284 - val_accuracy: 0.6911 - lr: 0.0010
# Epoch 39/50
# 486/486 [==============================] - 4s 8ms/step - loss: 0.9347 - accuracy: 0.6849 - val_loss: 0.9212 - val_accuracy: 0.6940 - lr: 0.0010
# Epoch 40/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9346 - accuracy: 0.6847 - val_loss: 0.9209 - val_accuracy: 0.6946 - lr: 0.0010
# Epoch 41/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9258 - accuracy: 0.6890 - val_loss: 0.9098 - val_accuracy: 0.6983 - lr: 1.0000e-04
# Epoch 42/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9238 - accuracy: 0.6888 - val_loss: 0.9079 - val_accuracy: 0.6986 - lr: 1.0000e-04
# Epoch 43/50
# 486/486 [==============================] - 4s 8ms/step - loss: 0.9218 - accuracy: 0.6909 - val_loss: 0.9089 - val_accuracy: 0.6983 - lr: 1.0000e-04
# Epoch 44/50
# 486/486 [==============================] - 4s 8ms/step - loss: 0.9224 - accuracy: 0.6897 - val_loss: 0.9093 - val_accuracy: 0.6981 - lr: 1.0000e-04
# Epoch 45/50
# 486/486 [==============================] - 4s 8ms/step - loss: 0.9207 - accuracy: 0.6897 - val_loss: 0.9086 - val_accuracy: 0.6978 - lr: 1.0000e-04
# Epoch 46/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9196 - accuracy: 0.6890 - val_loss: 0.9083 - val_accuracy: 0.6991 - lr: 1.0000e-04
# Epoch 47/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9188 - accuracy: 0.6909 - val_loss: 0.9070 - val_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 48/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9169 - accuracy: 0.6911 - val_loss: 0.9075 - val_accuracy: 0.6994 - lr: 1.0000e-04
# Epoch 49/50
# 486/486 [==============================] - 4s 7ms/step - loss: 0.9220 - accuracy: 0.6910 - val_loss: 0.9080 - val_accuracy: 0.6986 - lr: 1.0000e-04
# Epoch 50/50
# 486/486 [==============================] - 4s 8ms/step - loss: 0.9225 - accuracy: 0.6898 - val_loss: 0.9073 - val_accuracy: 0.6985 - lr: 1.0000e-04
# Computation time: 187.380 sec

# %% [markdown]
# 学習曲線の作図(保存したモデルを呼び出して実行)

# %%
model = load_model('model/EMGNet_Nina_ExA_2.h5')

#作図
x = range(1, epochnumber+1)
plt.plot(x, history.history['accuracy'])
plt.plot(x, history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Valid'], loc='lower right')
plt.show()

plt.plot(x, history.history['loss'])
plt.plot(x, history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
#plt.ylim(0, 8)
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Valid'], loc='upper right')
plt.show()

# %% [markdown]
# テスト・混同行列の作成(参考：https://newtechnologylifestyle.net/keras_fashion-mnist/)(https://kinpatucom821.hatenablog.com/entry/2018/08/30/215419)

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues
                          ):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

pred_y = model.predict(x_test)
pred_y_classes = np.argmax(pred_y,axis = 1) 
tue_y= np.argmax(y_test,axis = 1) 
confusion_mtx = confusion_matrix(tue_y, pred_y_classes) 
plot_confusion_matrix(confusion_mtx, classes = range(1, 13)) 
plt.show()

score = model.evaluate(x_test, y_test, verbose=0)
print('Loss:', score[0], '（損失関数値 - 0に近いほど正解に近い）') 
print('Accuracy:', score[1] * 100, '%', '（精度 - 100% に近いほど正解に近い）')
# Out:
# 971/971 [==============================] - 2s 1ms/step
# Confusion matrix, without normalization
# [[2353  102   54   40  202  234   89   49   37  117   56   37]
#  [ 110 2020   71  139   17   18   22   15   16   50   42   96]
#  [  74   72 1321  157   20   28    4    3   20   13   17  261]
#  [  90  176   70 1856   16   29    6   18   10   48   20   39]
#  [ 228   45   24   24 1664   78   75   26   24   53   15   10]
#  [ 233   33   15   38   62 2155   65  107   67  200   69   18]
#  [ 115   48    7   28   75  123 1582   90   90   83   42   14]
#  [  70   24   18   22   29  133   59 1925   87  217   48   16]
#  [  72   45   28   44   14  120   96   93 1758  333   89   14]
#  [  96   72   13   38   12  146   57   59  184 2152  130   27]
#  [  54   63   34   28   10  129   25   40   92  234 1842   45]
#  [  89  202  393   73    7    8   15   18    5   31   41 1261]]
# Loss: 0.8875989317893982 （損失関数値 - 0に近いほど正解に近い）
# Accuracy: 70.47781348228455 % （精度 - 100% に近いほど正解に近い）
